# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns

# %%
import matplotlib.pylab as plt

# %%
df = pd.read_csv(r'IT_Salary_Survey_EU_2020.csv')
df = pd.read_csv(r'IT_Salary_Survey_EU_2019.csv')
df = pd.read_csv(r'IT_Salary_Survey_EU_2018.csv')

# %%
data = pd.read_csv(r'IT_Salary_Survey_EU_2020.csv')

# %%
df.head(6)
# Out:
#              Timestamp   Age Gender     City                       Position  \
# 0  14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1  14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2  14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3  14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4  14/12/2018 12:50:31  39.0      M  München                    UX Designer
# 5  14/12/2018 12:52:24  37.0      M  München                Project Manager
#
#    Years of experience Your level  Current Salary  Salary one year ago  \
# 0                 11.0     Senior         77000.0              76200.0
# 1                  8.0     Senior         65000.0              55000.0
# 2                 10.0     Senior         88000.0              73000.0
# 3                  6.0     Senior         78000.0              55000.0
# 4                 10.0     Senior         69000.0              60000.0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                Timestamp   Age Gender     City                       Position  \
# 0    14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1    14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2    14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3    14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4    14/12/2018 12:50:31  39.0      M  München                    UX Designer
# ..                   ...   ...    ...      ...                            ...
# 760  03/06/2020 20:12:51  40.0      M     Köln          Java Developer junior
# 761  28/07/2020 04:03:13   NaN      M     Köln              E.g. C# Developer
# 762  28/07/2020 04:03:20   NaN      M     Köln              E.g. C# Developer
# 763  26/08/2020 09:06:44   NaN    NaN      NaN                            NaN
# 764  21/09/2020 01:47:10  31.0      F  München                            Pm
#
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                               0
# Age                                    93
# Gender                                 14
# City                                   29
# Position                               28
# Years of experience                    33
# Your level                             22
# Current Salary                         15
# Salary one year ago                   169
# Salary two years ago                  302
# Are you getting any Stock Options?     23
# Main language at work                  15
# Company size                           15
# Company type                           35
# dtype: int64

# %%
sns.scatterplot(x='Position', y='Current Salary', data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
x = ['Age', 'Gender', 'City', 'Position']
y = [93, 14, 23, 28]

# Create a new figure and axes
fig, ax = plt.subplots()

# Create a bar plot
ax.bar(x, y)

# Add a title and axis labels
ax.set_title('Sample Bar Plot')
ax.set_xlabel('Demographics')
ax.set_ylabel('Values')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Age', 'Gender', 'City', 'Position']
sizes = [93, 14, 29, 28]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

# Plot
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', startangle=90)

# Add a legend
plt.legend(labels, loc="best")

# Add a title
plt.title("Demographics")

# Show the plot
plt.show()

# %%
ax.set_xlim([-5, 5]) 
# for some white space on the chart ... 
lower, upper = ax.get_ylim() 
ax.set_ylim([lower-1, upper+1])
# Out:
# (-1.0, 98.65)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some sample data
x = ['Age', 'Gender', 'City', 'Position']
y = [93, 14, 23, 28]

# Create a bar chart
plt.bar(x, y)

# Add labels and a title
plt.xlabel('values')
plt.ylabel('demographics')
plt.title('Bar Graph')

# Display the chart
plt.show()

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position', 'Years of experience',
#        'Your level', 'Current Salary', 'Salary one year ago',
#        'Salary two years ago', 'Are you getting any Stock Options?',
#        'Main language at work', 'Company size', 'Company type'],
#       dtype='object')

# %%
pip install jupyter_contrib_nbextensions
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
'jupyter contrib nbextension install --waka_3811acc6-65ec-4c04-a104-4a3ff91efdc2'
# Out:
# 'jupyter contrib nbextension install --waka_3811acc6-65ec-4c04-a104-4a3ff91efdc2'

# %%
'jupyter nbextensions_configurator enable'
# Out:
# 'jupyter nbextensions_configurator enable'

# %%
'pip install wakatime'
# Out:
# 'pip install wakatime'

# %%
import os

os.environ['WAKATIME_API_KEY'] = 'waka_3811acc6-65ec-4c04-a104-4a3ff91efdc2'

# %%
 'jupyter nbextension enable --waka_3811acc6-65ec-4c04-a104-4a3ff91efdc2'
# Out:
# 'jupyter nbextension enable --waka_3811acc6-65ec-4c04-a104-4a3ff91efdc2'

# %%
data = pd.read_csv(r'IT_Salary_Survey_EU_2018.csv')

# %%
df.head(7)
# Out:
#              Timestamp   Age Gender     City                       Position  \
# 0  14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1  14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2  14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3  14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4  14/12/2018 12:50:31  39.0      M  München                    UX Designer
# 5  14/12/2018 12:52:24  37.0      M  München                Project Manager
# 6  14/12/2018 12:53:47   NaN      M   Berlin       Senior Android Developer
#
#    Years of experience Your level  Current Salary  Salary one year ago  \
# 0                 11.0     Senior         77000.0              76200.0
# 1                  8.0     Senior         65000.0              55000.0
# 2                 10.0     Senior         88000.0              73000.0
# 3                  6.0     Senior         78000.0              55000.0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                Timestamp   Age Gender     City                       Position  \
# 0    14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1    14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2    14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3    14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4    14/12/2018 12:50:31  39.0      M  München                    UX Designer
# ..                   ...   ...    ...      ...                            ...
# 760  03/06/2020 20:12:51  40.0      M     Köln          Java Developer junior
# 761  28/07/2020 04:03:13   NaN      M     Köln              E.g. C# Developer
# 762  28/07/2020 04:03:20   NaN      M     Köln              E.g. C# Developer
# 763  26/08/2020 09:06:44   NaN    NaN      NaN                            NaN
# 764  21/09/2020 01:47:10  31.0      F  München                            Pm
#
# ...

# %%
data.shape
# Out:
# (765, 14)

# %%
# Plot a histogram of the salaries
sns.histplot(data['Current Salary'], kde=False)
plt.title('Histogram of Salaries')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %%
# Plot a box plot of the salaries by gender
sns.boxplot(x='Gender', y='Current Salary', data=data)
plt.title('Box Plot of Salaries by Gender')
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.show()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                Timestamp   Age Gender     City                       Position  \
# 0    14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1    14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2    14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3    14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4    14/12/2018 12:50:31  39.0      M  München                    UX Designer
# ..                   ...   ...    ...      ...                            ...
# 760  03/06/2020 20:12:51  40.0      M     Köln          Java Developer junior
# 761  28/07/2020 04:03:13   NaN      M     Köln              E.g. C# Developer
# 762  28/07/2020 04:03:20   NaN      M     Köln              E.g. C# Developer
# 763  26/08/2020 09:06:44   NaN    NaN      NaN                            NaN
# 764  21/09/2020 01:47:10  31.0      F  München                            Pm
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load data into a pandas DataFrame
data = pd.read_csv(r'IT_Salary_Survey_EU_2018.csv')
# Create scatter plot
plt.scatter(x=data['Age'], y=data['Current Salary'])

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Current Salary')
plt.title('Scatter Plot')

# Show plot
plt.show()

# %%
data = pd.read_csv(r'IT_Salary_Survey_EU_2019.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                Timestamp   Age Gender     City                       Position  \
# 0    14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1    14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2    14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3    14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4    14/12/2018 12:50:31  39.0      M  München                    UX Designer
# ..                   ...   ...    ...      ...                            ...
# 760  03/06/2020 20:12:51  40.0      M     Köln          Java Developer junior
# 761  28/07/2020 04:03:13   NaN      M     Köln              E.g. C# Developer
# 762  28/07/2020 04:03:20   NaN      M     Köln              E.g. C# Developer
# 763  26/08/2020 09:06:44   NaN    NaN      NaN                            NaN
# 764  21/09/2020 01:47:10  31.0      F  München                            Pm
#
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                               0
# Age                                    93
# Gender                                 14
# City                                   29
# Position                               28
# Years of experience                    33
# Your level                             22
# Current Salary                         15
# Salary one year ago                   169
# Salary two years ago                  302
# Are you getting any Stock Options?     23
# Main language at work                  15
# Company size                           15
# Company type                           35
# dtype: int64

# %%
data.shape
# Out:
# (991, 23)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position', 'Years of experience',
#        'Your level', 'Current Salary', 'Salary one year ago',
#        'Salary two years ago', 'Are you getting any Stock Options?',
#        'Main language at work', 'Company size', 'Company type'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Plot a box plot of the salaries by gender
sns.boxplot(x='Gender', y='Age', data=data)
plt.title('Box Plot of Age by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
# Create scatter plot
plt.scatter(x=data['Age'], y=data['Years of experience'])

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Current Salary')
plt.title('Scatter Plot')

# Show plot
plt.show()

# %%
data.head(2)
# Out:
#            Zeitstempel   Age Gender    City Seniority level  \
# 0  02.12.2019 11:18:26  33.0   Male  Berlin          Senior
# 1  02.12.2019 11:18:35  29.0   Male  Berlin          Middle
#
#   Position (without seniority)  Years of experience  \
# 0          Fullstack Developer                   13
# 1            Backend Developer                    3
#
#   Your main technology / programming language  \
# 0                                         PHP
# 1                                      Python
#
#    Yearly brutto salary (without bonus and stocks)  Yearly bonus  ...  \
# 0                                          64000.0        1000.0  ...
# 1                                          55000.0           NaN  ...
#
#    Yearly stocks one year ago. Only answer if staying in same country  \
# 0                                                NaN
# 1                                                NaN
#
#    Number of vacation days  Number of home office days per month  \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position', 'Years of experience',
#        'Your level', 'Current Salary', 'Salary one year ago',
#        'Salary two years ago', 'Are you getting any Stock Options?',
#        'Main language at work', 'Company size', 'Company type'],
#       dtype='object')

# %%
df.shape
# Out:
# (765, 14)

# %%
data.shape
# Out:
# (991, 21)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the sample dataset
data = pd.read_csv(r'IT_Salary_Survey_EU_2019.csv')

# Create a bar chart
plt.bar(data['Gender'], data['Age'], color=['pink', 'blue', 'gray'])

# Add labels and title
plt.xlabel('Gender')
plt.ylabel('Current Salary')
plt.title('Comparison of Salaries by Gender')

# Show the plot
plt.show()

# %%
# Load the sample dataset
data = pd.read_csv(r'IT_Salary_Survey_EU_2019.csv')
# Input the current salary and salary two years ago
current_salary = float(input("Enter your current salary: "))
salary_two_years_ago = float(input("Enter your salary two years ago: "))

# Calculate the percentage change in salary
percentage_change = ((current_salary - salary_two_years_ago) / salary_two_years_ago) * 100

# Print the percentage change in salary
print("Your salary has changed by {:.2f}% in the past two years".format(percentage_change))
# Out:
# Enter your current salary: 2500
# Enter your salary two years ago: 250
# Your salary has changed by 900.00% in the past two years

# %%
import matplotlib.pyplot as plt
# Load the sample dataset
data = pd.read_csv(r'IT_Salary_Survey_EU_2019.csv')

# Create a figure and axis for the pie chart
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs = axs.flatten()

# Create a pie chart for each category
categories = [age, gender, position, salary]
titles = ['Age', 'Gender', 'Position', 'Current Salary']

for i in range(len(categories)):
    unique_categories = list(set(categories[i]))
    count_categories = [categories[i].count(j) for j in unique_categories]
    axs[i].pie(count_categories, labels=unique_categories, autopct='%1.1f%%', startangle=90)
    axs[i].set_title(titles[i])

plt.show()
